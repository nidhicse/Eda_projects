# %%
import pandas as pd
df=pd.read_csv("Avocado.csv")
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
df.head(10)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5           5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6           6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7           7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8           8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9           9  2015-10-25          1.07      74338.76   842.40   64757.44
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
# 5   43.61     6683.91     6556.47      127.44          0.0  conventional
# 6   93.26     8318.86     8196.81      122.05          0.0  conventional
# 7   80.00     6829.22     6266.85      562.37          0.0  conventional
# 8   85.34    11388.36    11104.53      283.83          0.0  conventional
# 9  113.00     8625.92     8061.47      564.45          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany
# 5  2015  Albany
# 6  2015  Albany
# 7  2015  Albany
# 8  2015  Albany
# 9  2015  Albany

# %%
df.tail(3)
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# std    1.074641e+05  9.862424e+05  7.461785e+05  2.439660e+05   17692.894652
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00       0.000000
# 25%    0.000000e+00  5.088640e+03  2.849420e+03  1.274700e+02       0.000000
# 50%    1.849900e+02  3.974383e+04  2.636282e+04  2.647710e+03       0.000000
# 75%    6.243420e+03  1.107834e+05  8.333767e+04  2.202925e+04     132.500000
# max    2.546439e+06  1.937313e+07  1.338459e+07  5.719097e+06  551693.650000
#
#                year
# count  18249.000000
# mean    2016.147899
# std        0.939938
# min     2015.000000
# 25%     2015.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2018.000000

# %%
print(df["AveragePrice"].quantile(0.25))
print(df["Total Volume"].std())
print(df["4046"].mean())
print(df["Small Bags"].var())
print(df["XLarge Bags"].mode())
print(df["AveragePrice"][df["AveragePrice"]>2])
# Out:
# 1.1
# 3453545.3553994815
# 293008.4245306592
# 556782376190.576
# 0    0.0
# Name: XLarge Bags, dtype: float64
# 3231     2.07
# 3232     2.07
# 4999     2.07
# 5000     2.20
# 6050     2.06
#          ...
# 18111    2.22
# 18113    2.27
# 18116    2.30
# 18126    2.02
# 18127    2.03
# Name: AveragePrice, Length: 1385, dtype: float64

# %%
import pandas as pd
df=pd.read_csv("Avocado.csv")
df["Date"]=pd.to_datetime(df["Date"])
albany_df=df[df["region"]=="Albany"]
albany_df.set_index("Date",inplace=True)
albany_df["AveragePrice"].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
albany_df.sort_index(inplace=True)
albany_df["AveragePrice"].rolling(25).mean().plot()
# Out:
# /var/folders/9s/v2wd_mfs2bd8t2400gj5kq0c0000gn/T/ipykernel_82025/1517763101.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   albany_df.sort_index(inplace=True)
# <Axes: xlabel='Date'>

# %%
albany_df["price25ma"]=albany_df["AveragePrice"].rolling(25).mean()
albany_df.head(30)
# Out:
# /var/folders/9s/v2wd_mfs2bd8t2400gj5kq0c0000gn/T/ipykernel_82025/2498090286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   albany_df["price25ma"]=albany_df["AveragePrice"].rolling(25).mean()
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225    4770  \
# Date
# 2015-01-04          51          1.22      40873.28  2819.50  28287.42   49.90
# 2015-01-04          51          1.79       1373.95    57.42    153.88    0.00
# 2015-01-11          50          1.24      41195.08  1002.85  31640.34  127.12
# 2015-01-11          50          1.77       1182.56    39.00    305.12    0.00
# 2015-01-18          49          1.17      44511.28   914.14  31540.32  135.77
# 2015-01-18          49          1.93       1118.47     8.02    178.78    0.00
# 2015-01-25          48          1.06      45147.50   941.38  33196.16  164.14
# 2015-01-25          48          1.89       1115.89    14.87    148.72    0.00
# 2015-02-01          47          0.99      70873.60  1353.90  60017.20  179.32
# 2015-02-01          47          1.83       1228.51    33.12     99.36    0.00
# 2015-02-08          46          0.99      51253.97  1357.37  39111.81  163.25
# 2015-02-08          46          1.59       1770.87    27.36    152.74    0.00
# 2015-02-15          45          1.06      41567.62   986.66  30045.51  222.42
# 2015-02-15          45          1.81       1182.30    22.74     83.02    0.00
# 2015-02-22          44          1.82       1152.33    11.34     31.76    0.00
# 2015-02-22          44          1.07      45675.05  1088.38  35056.13  151.00
# 2015-03-01          43          1.76       1663.35    32.82    105.25    0.00
# 2015-03-01          43          0.99      55595.74   629.46  45633.34  181.49
# 2015-03-08          42          1.79       1626.32    49.73    331.14    0.00
# 2015-03-08          42          1.07      40507.36   795.68  30370.64  159.05
# 2015-03-15          41          1.79       1473.56    19.18    164.73    0.00
# 2015-03-15          41          1.11      43045.79  2128.26  30447.17   99.67
# 2015-03-22          40          1.86       1375.02    40.57    326.78    0.00
# 2015-03-22          40          1.12      46346.85  2141.83  34313.56  141.80
# 2015-03-29          39          1.93       1082.44    24.75    173.26    0.00
# 2015-03-29          39          1.02      67799.08  1402.28  58623.22   89.50
# 2015-04-05          38          1.16      47362.13   961.77  35577.66   93.76
# 2015-04-05          38          1.93       1526.10    15.75    202.52    0.00
# 2015-04-12          37          1.76       1634.59    51.75     93.38    0.00
# 2015-04-12          37          1.13      48364.29   864.27  30374.15   21.50
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-01-04     9716.46     9186.93      529.53         0.00  conventional
# 2015-01-04     1162.65     1162.65        0.00         0.00       organic
# 2015-01-11     8424.77     8036.04      388.73         0.00  conventional
# 2015-01-11      838.44      838.44        0.00         0.00       organic
# 2015-01-18    11921.05    11651.09      269.96         0.00  conventional
# 2015-01-18      931.67      931.67        0.00         0.00       organic
# 2015-01-25    10845.82    10103.35      742.47         0.00  conventional
# 2015-01-25      952.30      952.30        0.00         0.00       organic
# 2015-02-01     9323.18     9170.82      152.36         0.00  conventional
# 2015-02-01     1096.03     1096.03        0.00         0.00       organic
# 2015-02-08    10621.54    10113.10      508.44         0.00  conventional
# 2015-02-08     1590.77     1590.77        0.00         0.00       organic
# 2015-02-15    10313.03     9979.87      333.16         0.00  conventional
# 2015-02-15     1076.54     1076.54        0.00         0.00       organic
# 2015-02-22     1109.23     1109.23        0.00         0.00       organic
# 2015-02-22     9379.54     9000.16      379.38         0.00  conventional
# 2015-03-01     1525.28     1525.28        0.00         0.00       organic
# 2015-03-01     9151.45     8986.06      165.39         0.00  conventional
# 2015-03-08     1245.45     1245.45        0.00         0.00       organic
# 2015-03-08     9181.99     8827.55      354.44         0.00  conventional
# 2015-03-15     1289.65     1289.65        0.00         0.00       organic
# 2015-03-15    10370.69     9989.59      381.10         0.00  conventional
# 2015-03-22     1007.67     1007.67        0.00         0.00       organic
# 2015-03-22     9749.66     9252.60      497.06         0.00  conventional
# 2015-03-29      884.43      884.43        0.00         0.00       organic
# 2015-03-29     7684.08     7208.49      475.59         0.00  conventional
# 2015-04-05    10728.94     9869.16      755.61       104.17  conventional
# 2015-04-05     1307.83     1307.83        0.00         0.00       organic
# 2015-04-12     1489.46     1489.46        0.00         0.00       organic
# 2015-04-12    17104.37    16438.49      665.88         0.00  conventional
#
#             year  region  price25ma
# Date
# 2015-01-04  2015  Albany        NaN
# 2015-01-04  2015  Albany        NaN
# 2015-01-11  2015  Albany        NaN
# 2015-01-11  2015  Albany        NaN
# 2015-01-18  2015  Albany        NaN
# 2015-01-18  2015  Albany        NaN
# 2015-01-25  2015  Albany        NaN
# 2015-01-25  2015  Albany        NaN
# 2015-02-01  2015  Albany        NaN
# 2015-02-01  2015  Albany        NaN
# 2015-02-08  2015  Albany        NaN
# 2015-02-08  2015  Albany        NaN
# 2015-02-15  2015  Albany        NaN
# 2015-02-15  2015  Albany        NaN
# 2015-02-22  2015  Albany        NaN
# 2015-02-22  2015  Albany        NaN
# 2015-03-01  2015  Albany        NaN
# 2015-03-01  2015  Albany        NaN
# 2015-03-08  2015  Albany        NaN
# 2015-03-08  2015  Albany        NaN
# 2015-03-15  2015  Albany        NaN
# 2015-03-15  2015  Albany        NaN
# 2015-03-22  2015  Albany        NaN
# 2015-03-22  2015  Albany        NaN
# 2015-03-29  2015  Albany     1.4660
# 2015-03-29  2015  Albany     1.4580
# 2015-04-05  2015  Albany     1.4328
# 2015-04-05  2015  Albany     1.4604
# 2015-04-12  2015  Albany     1.4600
# 2015-04-12  2015  Albany     1.4584

# %%
albany_df=albany_df.dropna()
albany_df.head(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225   4770  \
# Date
# 2015-03-29          39          1.93       1082.44    24.75    173.26   0.00
# 2015-03-29          39          1.02      67799.08  1402.28  58623.22  89.50
# 2015-04-05          38          1.16      47362.13   961.77  35577.66  93.76
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-03-29      884.43      884.43        0.00         0.00       organic
# 2015-03-29     7684.08     7208.49      475.59         0.00  conventional
# 2015-04-05    10728.94     9869.16      755.61       104.17  conventional
#
#             year  region  price25ma
# Date
# 2015-03-29  2015  Albany     1.4660
# 2015-03-29  2015  Albany     1.4580
# 2015-04-05  2015  Albany     1.4328

# %%
# to avoid these warnings
albany_df=df.copy()[df["region"]=="Albany"]
albany_df.set_index("Date",inplace=True)
albany_df.sort_index(inplace=True)
albany_df["AveragePrice"].rolling(25).mean().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
list(set(df["region"].values.tolist()))
# Out:
# ['PhoenixTucson',
#  'Indianapolis',
#  'BaltimoreWashington',
#  'Atlanta',
#  'Columbus',
#  'GrandRapids',
#  'West',
#  'Spokane',
#  'Boston',
#  'Seattle',
#  'Louisville',
#  'WestTexNewMexico',
#  'California',
#  'Midsouth',
#  'Northeast',
#  'Roanoke',
#  'StLouis',
#  'Tampa',
#  'DallasFtWorth',
#  'NorthernNewEngland',
#  'SouthCentral',
#  'NewOrleansMobile',
#  'Boise',
#  'NewYork',
#  'HarrisburgScranton',
#  'MiamiFtLauderdale',
#  'HartfordSpringfield',
#  'SanDiego',
#  'Southeast',
#  'Detroit',
#  'LosAngeles',
#  'TotalUS',
#  'GreatLakes',
#  'Portland',
#  'SouthCarolina',
#  'Syracuse',
#  'Jacksonville',
#  'Plains',
#  'Sacramento',
#  'SanFrancisco',
#  'LasVegas',
#  'Chicago',
#  'BuffaloRochester',
#  'Orlando',
#  'RichmondNorfolk',
#  'Denver',
#  'Houston',
#  'Nashville',
#  'Albany',
#  'Philadelphia',
#  'Pittsburgh',
#  'Charlotte',
#  'RaleighGreensboro',
#  'CincinnatiDayton']

# %%
df["region"].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
set(df["region"].values.tolist())
# Out:
# {'Albany',
#  'Atlanta',
#  'BaltimoreWashington',
#  'Boise',
#  'Boston',
#  'BuffaloRochester',
#  'California',
#  'Charlotte',
#  'Chicago',
#  'CincinnatiDayton',
#  'Columbus',
#  'DallasFtWorth',
#  'Denver',
#  'Detroit',
#  'GrandRapids',
#  'GreatLakes',
#  'HarrisburgScranton',
#  'HartfordSpringfield',
#  'Houston',
#  'Indianapolis',
#  'Jacksonville',
#  'LasVegas',
#  'LosAngeles',
#  'Louisville',
#  'MiamiFtLauderdale',
#  'Midsouth',
#  'Nashville',
#  'NewOrleansMobile',
#  'NewYork',
#  'Northeast',
#  'NorthernNewEngland',
#  'Orlando',
#  'Philadelphia',
#  'PhoenixTucson',
#  'Pittsburgh',
#  'Plains',
#  'Portland',
#  'RaleighGreensboro',
#  'RichmondNorfolk',
#  'Roanoke',
#  'Sacramento',
#  'SanDiego',
#  'SanFrancisco',
#  'Seattle',
#  'SouthCarolina',
#  'SouthCentral',
#  'Southeast',
#  'Spokane',
#  'StLouis',
#  'Syracuse',
#  'Tampa',
#  'TotalUS',
#  'West',
#  'WestTexNewMexico'}

# %%
df["region"].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
import pandas as pd
df=pd.read_csv("Avocado.csv")
df["Date"]=pd.to_datetime(df["Date"])
df.set_index("Date",inplace=True)
df.sort_index(inplace=True)
df
# Out:
#             Unnamed: 0  AveragePrice  Total Volume        4046       4225  \
# Date
# 2015-01-04          51          1.75      27365.89     9307.34    3844.81
# 2015-01-04          51          1.49      17723.17     1189.35   15628.27
# 2015-01-04          51          1.68       2896.72      161.68     206.96
# 2015-01-04          51          1.52      54956.80     3013.04   35456.88
# 2015-01-04          51          1.64       1505.12        1.27    1129.50
# ...                ...           ...           ...         ...        ...
# 2018-03-25           0          1.36     908202.13   142681.06  463136.28
# 2018-03-25           0          0.70    9010588.32  3999735.71  966589.50
# 2018-03-25           0          1.42     163496.70    29253.30    5080.04
# 2018-03-25           0          1.70     190257.38    29644.09   70982.10
# 2018-03-25           0          1.34    1774776.77    63905.98  908653.71
#
#                  4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-01-04     615.28    13598.46    13061.10      537.36         0.00
# 2015-01-04       0.00      905.55      905.55        0.00         0.00
# 2015-01-04       0.00     2528.08     2528.08        0.00         0.00
# 2015-01-04    1561.70    14925.18    11264.80     3660.38         0.00
# 2015-01-04       0.00      374.35      186.67      187.68         0.00
# ...               ...         ...         ...         ...          ...
# 2018-03-25  174975.75   127409.04   103579.41    22467.04      1362.59
# 2018-03-25   30130.82  4014132.29  3398569.92   546409.74     69152.63
# 2018-03-25       0.00   129163.36   109052.26    20111.10         0.00
# 2018-03-25       0.00    89631.19    89424.11      207.08         0.00
# 2018-03-25     843.45   801373.63   774634.09    23833.93      2905.61
#
#                     type  year              region
# Date
# 2015-01-04       organic  2015           Southeast
# 2015-01-04       organic  2015             Chicago
# 2015-01-04       organic  2015  HarrisburgScranton
# 2015-01-04  conventional  2015          Pittsburgh
# 2015-01-04       organic  2015               Boise
# ...                  ...   ...                 ...
# 2018-03-25  conventional  2018             Chicago
# 2018-03-25  conventional  2018        SouthCentral
# 2018-03-25       organic  2018        SouthCentral
# 2018-03-25       organic  2018          California
# 2018-03-25  conventional  2018             NewYork
#
# [18249 rows x 13 columns]

# %%
import pandas as pd
df=pd.read_csv("Avocado.csv")
df["Date"]=pd.to_datetime(df["Date"])
df.set_index("Date",inplace=True)
df.sort_index(inplace=True)
df
# Out:
#             Unnamed: 0  AveragePrice  Total Volume        4046       4225  \
# Date
# 2015-01-04          51          1.75      27365.89     9307.34    3844.81
# 2015-01-04          51          1.49      17723.17     1189.35   15628.27
# 2015-01-04          51          1.68       2896.72      161.68     206.96
# 2015-01-04          51          1.52      54956.80     3013.04   35456.88
# 2015-01-04          51          1.64       1505.12        1.27    1129.50
# ...                ...           ...           ...         ...        ...
# 2018-03-25           0          1.36     908202.13   142681.06  463136.28
# 2018-03-25           0          0.70    9010588.32  3999735.71  966589.50
# 2018-03-25           0          1.42     163496.70    29253.30    5080.04
# 2018-03-25           0          1.70     190257.38    29644.09   70982.10
# 2018-03-25           0          1.34    1774776.77    63905.98  908653.71
#
#                  4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2015-01-04     615.28    13598.46    13061.10      537.36         0.00
# 2015-01-04       0.00      905.55      905.55        0.00         0.00
# 2015-01-04       0.00     2528.08     2528.08        0.00         0.00
# 2015-01-04    1561.70    14925.18    11264.80     3660.38         0.00
# 2015-01-04       0.00      374.35      186.67      187.68         0.00
# ...               ...         ...         ...         ...          ...
# 2018-03-25  174975.75   127409.04   103579.41    22467.04      1362.59
# 2018-03-25   30130.82  4014132.29  3398569.92   546409.74     69152.63
# 2018-03-25       0.00   129163.36   109052.26    20111.10         0.00
# 2018-03-25       0.00    89631.19    89424.11      207.08         0.00
# 2018-03-25     843.45   801373.63   774634.09    23833.93      2905.61
#
#                     type  year              region
# Date
# 2015-01-04       organic  2015           Southeast
# 2015-01-04       organic  2015             Chicago
# 2015-01-04       organic  2015  HarrisburgScranton
# 2015-01-04  conventional  2015          Pittsburgh
# 2015-01-04       organic  2015               Boise
# ...                  ...   ...                 ...
# 2018-03-25  conventional  2018             Chicago
# 2018-03-25  conventional  2018        SouthCentral
# 2018-03-25       organic  2018        SouthCentral
# 2018-03-25       organic  2018          California
# 2018-03-25  conventional  2018             NewYork
#
# [18249 rows x 13 columns]

# %%
import pandas as pd
df=pd.read_csv("Avocado.csv")
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 18244    0.00    13498.67    13066.82      431.85          0.0       organic
# 18245    0.00     9264.84     8940.04      324.80          0.0       organic
# 18246  727.94     9394.11     9351.80       42.31          0.0       organic
# 18247  727.01    10969.54    10919.54       50.00          0.0       organic
# 18248  224.53    12014.15    11988.14       26.01          0.0       organic
#
#        year            region
# 0      2015            Albany
# 1      2015            Albany
# 2      2015            Albany
# 3      2015            Albany
# 4      2015            Albany
# ...     ...               ...
# 18244  2018  WestTexNewMexico
# 18245  2018  WestTexNewMexico
# 18246  2018  WestTexNewMexico
# 18247  2018  WestTexNewMexico
# 18248  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
import pandas as pd
df=pd.read_csv("Avocado.csv")
graph_df=pd.DataFrame()
for region in df["region"].unique():
    print(region)
    region_df=df.copy()[df["region"]==region]
    region_df.set_index("Date",inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f"{region}_25ma"]=region_df["AveragePrice"].rolling(25).mean()
    if graph_df.empty:
        graph_df=region_df[[f"{region}_25ma"]]
    else:
        graph_df=graph_df.join(region_df[f"{region}_25ma"])
graph_df
# Out:
# Albany
# Atlanta
# BaltimoreWashington
# Boise
# Boston
# BuffaloRochester
# California
# Charlotte
# Chicago
# CincinnatiDayton
# Columbus
# DallasFtWorth
# Denver
# Detroit
# GrandRapids
# GreatLakes
# HarrisburgScranton
# HartfordSpringfield
# Houston
# Indianapolis

# %%
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
import pandas as pd
df=pd.read_csv("Avocado.csv")
df=df.copy()[df["type"]=="organic"]
df["Date"]=pd.to_datetime(df["Date"])
df.sort_values(by="Date",ascending=True,inplace=True)
graph_df=pd.DataFrame()
for region in df["region"].unique()[:16]:
    print(region)
    region_df=df.copy()[df["region"]==region]
    region_df.set_index("Date",inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f"{region}_25ma"]=region_df["AveragePrice"].rolling(25).mean()
    if graph_df.empty:
        graph_df=region_df[[f"{region}_25ma"]]
    else:
        graph_df=graph_df.join(region_df[f"{region}_25ma"])
graph_df.dropna().plot(figsize=(8,5),legend=False)
# Out:
# California
# LasVegas
# PhoenixTucson
# BuffaloRochester
# Spokane
# LosAngeles
# Philadelphia
# Boston
# StLouis
# Louisville
# Orlando
# Southeast
# Boise
# MiamiFtLauderdale
# NorthernNewEngland
# BaltimoreWashington
# <Axes: xlabel='Date'>
